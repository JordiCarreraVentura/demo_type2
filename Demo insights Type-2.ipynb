# %%
from DocumentGetter import Cluster, DocumentGetter

from RenderJSON import json, display, RenderJSON

from __init__ import from_pickle

# %%
with open('data/once.json') as rd:
    once_g = json.load(rd)
once_d = DocumentGetter('data/once.p')

with open('data/bid.json') as rd:
    bid_g = json.load(rd)
bid_d = DocumentGetter('data/bid.p')

# %% [markdown]
# # ONCE

# %% [markdown]
# ## Bubble browser

# %%
r = RenderJSON(once_g)
display(r)
# Out:
# <div id="e3dae373-63b9-4ffe-8c57-8cb53a637d16" style="height: 600px; width:100%;"></div>

# %% [markdown]
# ## Document browser

# %%
once_d[None]

# %% [markdown]
# # BID

# %% [markdown]
# ## Bubble browser

# %%
r = RenderJSON(bid_g)
display(r)
# Out:
# <div id="19ad56ee-9855-4688-ad4e-58407214e211" style="height: 600px; width:100%;"></div>

# %% [markdown]
# ## Document browser

# %%
bid_d[None]
